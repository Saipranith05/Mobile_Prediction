# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
sns.boxplot(df["size"]) # total_bill,tip,size
# Out:
# <Axes: ylabel='size'>

# %%
df["total_bill"].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
q1 = df.describe()["total_bill"]["25%"]
q3 = df.describe()["total_bill"]["75%"]
iqr = q3 - q1

lower_limit = q1 - 1.5 * iqr
upper_limit = q3 + 1.5 * iqr

# %%
df["total_bill"].clip(lower_limit, upper_limit, inplace=True)
# Out:
# C:\Users\Akshitha\AppData\Local\Temp\ipykernel_25584\1812915643.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["total_bill"].clip(lower_limit, upper_limit, inplace=True)

# %%
sns.boxplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
q1 = df.describe()["tip"]["25%"]
q3 = df.describe()["tip"]["75%"]
iqr = q3 - q1

lower_limit = q1 - 1.5 * iqr
upper_limit = q3 + 1.5 * iqr

# %%
df["tip"].clip(lower_limit, upper_limit, inplace=True)
# Out:
# C:\Users\Akshitha\AppData\Local\Temp\ipykernel_25584\3996287496.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["tip"].clip(lower_limit, upper_limit, inplace=True)

# %%
sns.boxplot(df["tip"])
# Out:
# <Axes: ylabel='tip'>

# %%
q1 = df.describe()["size"]["25%"]
q3 = df.describe()["size"]["75%"]
iqr = q3 - q1

lower_limit = q1 - 1.5 * iqr
upper_limit = q3 + 1.5 * iqr

# %%
df["size"].clip(lower_limit, upper_limit, inplace=True)
# Out:
# C:\Users\Akshitha\AppData\Local\Temp\ipykernel_25584\1648572593.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["size"].clip(lower_limit, upper_limit, inplace=True)
# C:\Users\Akshitha\AppData\Local\Temp\ipykernel_25584\1648572593.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df["size"].clip(lower_limit, upper_limit, inplace=True)

# %%
sns.boxplot(df["size"])
# Out:
# <Axes: ylabel='size'>

# %%
#Encoding
df.head() #---> sex, smoker, day, time
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner   2.0
# 1       10.34  1.66    Male     No  Sun  Dinner   3.0
# 2       21.01  3.50    Male     No  Sun  Dinner   3.0
# 3       23.68  3.31    Male     No  Sun  Dinner   2.0
# 4       24.59  3.61  Female     No  Sun  Dinner   4.0

# %%
d1 = {"Male":0, "Female":1}
df["sex"] = df["sex"].map(d1)

# %%
d2 = {"No":0, "Yes":1}
df["smoker"]=df["smoker"].map(d2)

# %%
d3 = {"Thur":0, "Fri":1,"Sat":2,"Sun":3}
df["day"]=df["day"].map(d3)

# %%
d4 = {"Lunch":0, "Dinner":1}
df["time"]=df["time"].map(d4)

# %%
df.head()
# Out:
#    total_bill   tip sex smoker day time  size
# 0       16.99  1.01   1      0   3    1   2.0
# 1       10.34  1.66   0      0   3    1   3.0
# 2       21.01  3.50   0      0   3    1   3.0
# 3       23.68  3.31   0      0   3    1   2.0
# 4       24.59  3.61   1      0   3    1   4.0

# %%
df["day"].value_counts()
# Out:
# day
# 2    87
# 3    76
# 0    62
# 1    19
# Name: count, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(25,12))
plt.subplot(1,5,1)
plt.pie(df["total_bill"])
plt.subplot(1,5,2)
plt.boxplot(df["size"])
plt.subplot(1,5,3)
sns.boxplot(df["tip"])
plt.subplot(1,5,4)
plt.plot(df["day"])
plt.subplot(1,5,5)
sns.heatmap(pd.crosstab(df["tip"], df["total_bill"]), annot=True)
plt.show()

# %%
x = df.drop(columns=["tip"])
y = df["tip"]

# %%
x.head()
# Out:
#    total_bill sex smoker day time  size
# 0       16.99   1      0   3    1   2.0
# 1       10.34   0      0   3    1   3.0
# 2       21.01   0      0   3    1   3.0
# 3       23.68   0      0   3    1   2.0
# 4       24.59   1      0   3    1   4.0

# %%
y.head()
# Out:
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# Name: tip, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
x_train.shape
# Out:
# (195, 6)

# %%
x_test.shape
# Out:
# (49, 6)

# %%
y_train.shape
# Out:
# (195,)

# %%
from sklearn.linear_model import LinearRegression
lin = LinearRegression()

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# prediction

y_pred = lin.predict(x_test)

# %%
# Evalution

from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
mse
# Out:
# np.float64(0.6527829234626754)

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# np.float64(0.807949827317684)

# %%
import joblib
joblib.dump(lin, "Tips.pkl")
# Out:
# ['Tips.pkl']

# %%
df.head()
# Out:
#    total_bill   tip sex smoker day time  size
# 0       16.99  1.01   1      0   3    1   2.0
# 1       10.34  1.66   0      0   3    1   3.0
# 2       21.01  3.50   0      0   3    1   3.0
# 3       23.68  3.31   0      0   3    1   2.0
# 4       24.59  3.61   1      0   3    1   4.0

# %%
cols = df.columns

# %%
df.columns = df.columns.str.strip()

# %%
df.columns = df.columns.str.strip().str.lower()

# %%
print(df.columns)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.columns = df.columns.str.strip().str.lower()

# %%
df.rename(columns={"actual_column_name": "tip"}, inplace=True)

# %%
for label in cols[:-1]:  # Loop through all columns except the last one
    plt.hist(df[df["tip"] == 1][label], color="blue", label="gamma", alpha=0.7, density=True)
    plt.hist(df[df["total_bill"] == 0][label], color="red", label="hadron", alpha=0.7, density=True)
    plt.title(label)
    plt.ylabel("Probability")
    plt.xlabel(label)
    plt.legend()
    plt.show()
# Out:
# c:\Users\Akshitha\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_histograms_impl.py:902: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges

# %%
pip install tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: tensorflow in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.28.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (73.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.67.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.2)
# Requirement already satisfied: namex in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\akshitha\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf

# %%
demo = tf.keras.Sequential([
   tf.keras.layers.Dense(32, activation='relu', input_shape=(10,)),
   tf.keras.layers.Dense(32, activation='relu'),
   tf.keras.layers.Dense(1, activation='sigmoid') 
])

demo.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='binary)corssentropy',
           metrics=["accuracy"])
# Out:
# c:\Users\Akshitha\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label="val_loss")
    plt.xlabel("Epoch")
    plt.ylabel('Binary crossentropy')
    plt.lenged()
    plt.grid(True)
    plt.show()
    
def plot_accuracy(history):
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label="val_accuracy")
    plt.xlabel("Epoch")
    plt.ylabel('Accuracy')
    plt.lenged()
    plt.grid(True)
    plt.show()

# %%
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# x_train shape: (195, 6)
# y_train shape: (195, 1)

# %%
import numpy as np

y_train = np.array(y_train)  # Convert y_train to a NumPy array if it's a Series
if y_train.ndim == 1:
    y_train = y_train.reshape(-1, 1)  # Reshape to (num_samples, 1) if it's 1D

# %%
import numpy as np

if y_train.ndim == 1:  # Check if it's 1D
    y_train = np.array(y_train).reshape(-1, 1)  # Reshape to (num_samples, 1)
else:
    y_train = np.array(y_train)  # Ensure it's a NumPy array

# %%
demo = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(195,6)),  # Ensure input_shape matches x_train
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # For binary classification
])
# Out:
# c:\Users\Akshitha\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (195, 6)
# (195,)

# %%
import numpy as np

y_train = np.array(y_train).reshape(-1, 1)

# %%
y_train = y_train.reshape(-1, 1)

# %%
y_train = y_train.reshape(-1, 1)

# %%
demo.compile(optimizer=tf.keras.optimizers.Adam(0.001), 
             loss='binary_crossentropy',  # Use 'binary_crossentropy' for binary classification
             metrics=['accuracy'])

# %%
import tensorflow as tf
import numpy as np

# Assuming x_train and y_train are already defined and preprocessed

# Print shapes
print("x_train shape:", x_train.shape)  # Should print (195, 6)
print("y_train shape:", y_train.shape)  # Should print (195, 1)

# Reshape y_train if necessary (already correct in your case)
if y_train.ndim == 1:
    y_train = np.array(y_train).reshape(-1, 1)

# Define the model using an Input layer
demo = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(6,)),  # Specify the input shape directly
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')  # Output layer for binary classification
])

# Compile the model
demo.compile(optimizer=tf.keras.optimizers.Adam(0.001), 
             loss='binary_crossentropy', 
             metrics=['accuracy'])

# Fit the model
history = demo.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# x_train shape: (195, 6)
# y_train shape: (195, 1)
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.0000e+00 - loss: -13.8848 - val_accuracy: 0.0513 - val_loss: -15.8814
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: -16.3547 - val_accuracy: 0.0513 - val_loss: -19.1430
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: -20.4219 - val_accuracy: 0.0513 - val_loss: -22.5363
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: -22.0443 - val_accuracy: 0.0513 - val_loss: -26.1439
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: -27.0978 - val_accuracy: 0.0513 - val_loss: -30.1200
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0000e+00 - loss: -29.3715 - val_accuracy: 0.0513 - val_loss: -34.4147
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: -37.3996 - val_accuracy: 0.0513 - val_loss: -39.1875
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: -40.2011 - val_accuracy: 0.0513 - val_loss: -44.2669
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: -43.6543 - val_accuracy: 0.0513 - val_loss: -49.7289
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: -52.5298 - val_accuracy: 0.0513 - val_loss: -55.6824
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: -59.8965 - val_accuracy: 0.0513 - val_loss: -62.1179
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: -63.4764 - val_accuracy: 0.0513 - val_loss: -69.0015
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: -74.2245 - val_accuracy: 0.0513 - val_loss: -76.5076
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: -82.1405 - val_accuracy: 0.0513 - val_loss: -84.6405
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: -90.0284 - val_accuracy: 0.0513 - val_loss: -93.5126
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: -93.6145 - val_accuracy: 0.0513 - val_loss: -103.1260
# Epoch 17/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: -104.2004 - val_accuracy: 0.0513 - val_loss: -113.7268
# Epoch 18/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: -116.8714 - val_accuracy: 0.0513 - val_loss: -125.2696
# Epoch 19/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: -125.3997 - val_accuracy: 0.0513 - val_loss: -137.8383
# Epoch 20/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: -138.5015 - val_accuracy: 0.0513 - val_loss: -151.5607
# Epoch 21/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: -164.4609 - val_accuracy: 0.0513 - val_loss: -166.4481
# Epoch 22/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: -164.7034 - val_accuracy: 0.0513 - val_loss: -182.2541
# Epoch 23/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: -158.8906 - val_accuracy: 0.0513 - val_loss: -199.1850
# Epoch 24/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.0000e+00 - loss: -222.2296 - val_accuracy: 0.0513 - val_loss: -218.2533
# Epoch 25/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: -238.5149 - val_accuracy: 0.0513 - val_loss: -238.3541
# Epoch 26/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: -239.3923 - val_accuracy: 0.0513 - val_loss: -259.5827
# Epoch 27/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0000e+00 - loss: -288.5000 - val_accuracy: 0.0513 - val_loss: -282.8246
# Epoch 28/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0000e+00 - loss: